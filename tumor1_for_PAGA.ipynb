# %% [markdown]
# # Starting the PAGA project

# %% [markdown]
# ## Tumor 1 Data Overview: Six Clusters

# %%
tumor1 <- readRDS("tumor1.rds")

# %%
DimPlot(tumor1)
# Out:
# plot without title

# %% [markdown]
# ## Metadata

# %%
head(tumor1@meta.data)
# Out:
#                    nCount_RNA nFeature_RNA nCount_SCT nFeature_SCT
# AAACAGCCAGCAACAG-1 10314      3278         8571       3277
# AAACAGCCAGCCAGTT-1  1366       541         7074       1355
# AAACAGCCATAGACCC-1  1067       658         6328       1648
# AAACATGCAACACCTA-1  1745      1019         6407       1543
# AAACCAACAATTAGCT-1 14656      4434         8843       4065
# AAACCAACAATTTAGC-1 10714      3491         8684       3485
#                    seurat_clusters Phase old.ident cell_type
# AAACAGCCAGCAACAG-1 3               G2M   3         Aneuploid-lumsec-B
# AAACAGCCAGCCAGTT-1 1               G2M   8         Diploid-lumsec-like
# AAACAGCCATAGACCC-1 1               G1    8         Diploid-lumsec-like
# AAACATGCAACACCTA-1 0               S     0         Diploid-basal-like
# AAACCAACAATTAGCT-1 1               S     5         Diploid-lumsec-like
# AAACCAACAATTTAGC-1 1               G1    5         Diploid-lumsec-like

# %% [markdown]
# # Notes for Following the PAGA Tutorial

# %% [markdown]
# ### Data loading
#
# Import the data I give you like this:
#
# ```adata = sc.read_h5ad('tumor1.h5ad')```
#
# _Don't pull the Paul 15 data in line # 3_

# %% [markdown]
# ### Data processing
#
# 1. Use Leiden instead of Louvain
# 2. Try 3 resolutions (1.0,  0.5,  0.1) here:
#
# ```sc.tl.leiden(adata, resolution=1.0)```
#
# 3. Move forward with the lowest resolution.
#
# 4. Don't annotate yet
#
# skip this: ```adata.obs['louvain_anno'] = adata.obs['louvain']```

# %% [markdown]
# ### Visualization
#
# Show the cell type (original cluster #) and the leiden cluster in the paga graph plot, not the genes that the tutorial uses
#
# ```sc.pl.paga(adata, color=['cell_type','leiden'])```
#
# * Note: cell_types are numbers here, unlike actual names in the Seurat example

# %% [markdown]
# ### Stopping Point
#
# Stop after tutorial line # 28.
#
# Don't do gene change reconstruction yet.
